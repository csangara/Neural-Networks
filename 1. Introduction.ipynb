# %% [markdown]
# # Introduction to Neural Networks
#
# Hello, and welcome to the interactive python tutorial on neural networks! The purpose of this tutorial is to give you a conceptual understanding of neural networks, including its motivation, algorithm, and applications.
#
# The mathematics will be kept to a bare minimum, but it is rather essential to have a basic knowledge of linear algebra, mainly of matrix multiplication. (You can find some useful resources in the **References & Further Readings** section.) A background in calculus (yuck!) or programming isn't required, but it will better help to understand what is going on.
#
# Let's get started!

# %% [markdown]
# ## What is a Neural Network?
#
# Neural networks are one of the many models in **machine learning**, a field of study that, as described by Arthur Samuel,  "gives computers the ability to learn without being explicitly programmed." Machine learning has been gaining tremendous popularity over the last few decades, and it can be used in predicting, classifying, and clustering data.
#
# There are two types of machine learning: supervised learning and unsupervised learning. **Supervised learning** refers to algorithms in which the "right" answers are given. The data given to the machine is already labeled, an example being a dataset of house sizes that is already labeled with the corresponding prices. We can use then that information to predict the price of house sizes not in the dataset. In  **unsupervised learning**, however, there is no labeled 'answer.' The algorithm must try to make sense of the data by itself. In this tutorial, we will focus on supervised learning.
#
# Applications of machine learning range from the mundane e-mail spam classification and Netflix movie recommendations to the remarkable image recognition and autonomous driving. Neural networks are especially useful in classification problems, and are nowadays considered the state-of-the-art algorithm in solving speech and image recognition problems.
#
# ### Biological Motivation
#
# Neural networks, as its name suggests, is inspired by the human brain. The **neuron** is the main computational unit in the human brain (its picture is shown below).

# %%
from IPython.display import Image
Image('neuron.png')
# Image courtesy of wikimedia

# %% [markdown]
# Neurons use pulses of electricity to send messages to one another. The dendrite of a neuron receives a signal, processes it, and fires it to the axon terminal if a **threshold** value is exceeded.
#
# Artificial neurons in a neural network work in a similar way: it takes an input data, performs simple mathematical operations on it, and outputs the processed data.

# %%
Image('simplenn.png')

# %% [markdown]
# The 'network' above only consists of one input neuron and one output neuron, and as expected, it wouldn't be able to perform complicated tasks. In an actual implementation of neural networks, there will usually be one or more **hidden layers** between the **input layer** and the **output layer**. Below is an example of a neural network with two hidden layers.

# %%
Image('2442nn.png')

# %% [markdown]
# ### How It Works
#
# Each neuron has **weight** values associated to it, and these constrain how the input data is related to output data. You can visualize the weights as the line connecting one neuron to another.
#
# What an individual neuron does is take the input, multiply it with the weight, and pass the processed data (also called the **activation**) along to the next neuron. However, the neuron will only 'fire' an output if the activation is greater than its threshold value.
#
# Let's look at the simple network below. The activation being sent to the output layer is computed by:
#
# $$activation = (input1 \times weight1) + (input2 \times weight2) $$

# %%
Image('activation.png')

# %% [markdown]
# With a complicated network of several layers and many neurons, we can compute even the most complex functions by varying the values of the weights and thresholds. You might be asking: *how would you decide the values of the weights (and threshold) in the first place?*
#
# These values are obtained during the training period. That is, we feed **training data** with inputs $x$ and the correct output $y$ to our network. This could be points on a graph, images, or even audio clips. Through an iterative process, the weights are going to converge to a local optimum, and we can then use the network to classify new data.
#
# That's the basic idea of neural networks. In the next section, we will cover single-layer networks - McCulloch Pitts and perceptrons - which do not contain a hidden layer.

# %% [markdown]
# ## References & Further Readings
#
# - [A Basic Introduction to Neural Networks](http://www.webpages.ttu.edu/dleverin/neural_network/neural_networks.html)
# - [Coursera: Machine Learning](https://www.coursera.org/learn/machine-learning)
# - [What is a Neural Network?](http://www.ai-junkie.com/ann/evolved/nnt2.html)
# - [Matrix Multiplication](https://www.mathsisfun.com/algebra/matrix-multiplying.html)
